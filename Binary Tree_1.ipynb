# %%
class BinaryTree:

    def __init__(self, data):
        self.data = data
        self.leftchild = None
        self.rightchild = None
    
    def preOrder(self,root):
        if not root:
            return
        print(root.data)
        self.preOrder(root.leftchild)
        self.preOrder(root.rightchild)

    def inOrder(self, root):
        if not root:
            return
        self.inOrder(root.leftchild)
        print(root.data)
        self.inOrder(root.rightchild)

    def postOrder(self, root):
        if not root:
            return
        self.postOrder(root.leftchild)
        self.postOrder(root.rightchild)
        print(root.data)
    
    def count_nodes(self, root):
        count = 0
        if root == None:
            return 0 
        lc = self.count_nodes(root.leftchild)
        rc = self.count_nodes(root.rightchild)    
        return lc + rc + 1    
        return count
     
    def search(self, inorder, start, end, curr):     
        for i in range(start , end+1):
            if inorder[i] == curr:
                return i   
        return -1 
            
    index = 0
    def buildtree(self,  preorder, inorder, start, end):
        if start>end:
            return None     
        rootv = preorder[buildtree.index]
        buildtree.index = buildtree.index + 1
        root = BinaryTree(rootv)
        if start == end:
            return root
        pos = self.search(inorder, start,  end, rootv)
        root.leftchild = self.buildtree(preorder, inorder, start,pos-1 )
        print("left ->", root.leftchild.data)
        root.rightchild = self.buildtree(preorder, inorder,pos+1 , end )

        return node

N1 = BinaryTree("N1")
N2 = BinaryTree("N2")
N3 = BinaryTree("N3")
N4 = BinaryTree("N4")
N5 = BinaryTree("N5")
N6 = BinaryTree("N6")
N7 = BinaryTree("N7")
N8 = BinaryTree("N8")
N9 = BinaryTree("N9")
N10 = BinaryTree("N10")
N11 = BinaryTree("N11")



N1.leftchild = N2
N1.rightchild = N3
N2.leftchild = N4
N2.rightchild = N5
N3.leftchild = N6
N3.rightchild = N7
N4.leftchild = N8
N4.rightchild = N9
N5.leftchild = N10
N5.rightchild = N11

rootnode = N1
#N1.height(N1)
    
N1.count_nodes(N1)
# Out:
# 11

# %%
#Diameter of a BT. longest distance bw two nodes

# %%
class BinaryTree:
    
    
    
    def __init__(self, data):
        self.data = data
        self.leftchild = None
        self.rightchild = None
        
        
    def preOrder(self,root):
        if not root:
            return
    
        print(root.data)
        self.preOrder(root.leftchild)
        self.preOrder(root.rightchild)
    
    
    
    
    def postOrder(self, root):
        if not root:
            return
        
        self.postOrder(root.leftchild)
        self.postOrder(root.rightchild)
        print(root.data)
    
    def count_nodes(self, root):
        count = 0
        if root == None:
            return 0
        
        lc = self.count_nodes(root.leftchild)
        rc = self.count_nodes(root.rightchild)
        
        return lc + rc + 1
            
        
            
        return count
            
    
    def inOrder(self, root):
        if not root:
            return
    
    
        self.inOrder(root.leftchild)
        print(root.data)
        self.inOrder(root.rightchild)
        
        
    def height(self, root):
        if root == None:
            return 0
        
        l = self.height(root.leftchild)
        r = self.height(root.rightchild)
        
        return max(l,r) + 1
    
    
    def diameter(self, root):
        
        if root == None:
            return 0 
        
        hl = self.height(root.leftchild)
        hr = self.height(root.rightchild)
        mh = hl + hr + 2
        
        ll = self.diameter(root.leftchild)
        rr = self.diameter(root.rightchild)
        
        q = max(mh , max(ll , rr))
        
        return q
        
        
    
        
        

N1 = BinaryTree("N1")
N2 = BinaryTree("N2")
N3 = BinaryTree("N3")
N4 = BinaryTree("N4")
N5 = BinaryTree("N5")
N6 = BinaryTree("N6")
N7 = BinaryTree("N7")
N8 = BinaryTree("N8")
N9 = BinaryTree("N9")
N10 = BinaryTree("N10")
N11 = BinaryTree("N11")



N1.leftchild = N2
N1.rightchild = N3
N2.leftchild = N4
N2.rightchild = N5
N3.leftchild = N6
N3.rightchild = N7
N4.leftchild = N8
N4.rightchild = N9
N5.leftchild = N10
N5.rightchild = N11

rootnode = N1
#N1.height(N1)
    
N1.diameter(N1)
# Out:
# 7

# %%
class BinaryTree:
    
    
    
    def __init__(self, data):
        self.data = data
        self.leftchild = None
        self.rightchild = None
        
        self.path = []
        
        
    def preOrder(self,root):
        if not root:
            return
    
        print(root.data)
        self.preOrder(root.leftchild)
        self.preOrder(root.rightchild)
    
    
    
    
    def postOrder(self, root):
        if not root:
            return
        
        self.postOrder(root.leftchild)
        self.postOrder(root.rightchild)
        print(root.data)
    
    
    
    def inOrder(self, root):
        if not root:
            return
    
    
        self.inOrder(root.leftchild)
        print(root.data)
        self.inOrder(root.rightchild)
        
        
    def search(self, inorder, start, end, curr):
        
        for i in range(start , end+1):
            if inorder[i] == curr:
                return i
            
        return -1 
        

    
    def left_cloned(self, root):
        
        
        if root == None :
            return 
        
        l = BinaryTree(self.left_cloned(root.leftchild))
        r = BinaryTree(self.left_cloned(root.rightchild))
        
        
        copy = BinaryTree(root.data)
        root.leftchild = copy
        
        copy.leftchild = l
        root.rightchild = r
        
        
        self.inOrder(root) 
        
        
    def clone_to_normal(self, root):
        if root == None:
            return None
        
        l = BinaryTree(self.clone_to_normal(root.leftchild.leftchild))
        r = BinaryTree(self.clone_to_normal(root.rightchild))
        
        root.leftchild = l
        root.rightchild = r
        
 
    
N1 = BinaryTree("N1")
N2 = BinaryTree("N2")
N3 = BinaryTree("N3")
N4 = BinaryTree("N4")
N5 = BinaryTree("N5")
N6 = BinaryTree("N6")
N7 = BinaryTree("N7")
N8 = BinaryTree("N8")
N9 = BinaryTree("N9")
N10 = BinaryTree("N10")
N11 = BinaryTree("N11")



N1.leftchild = N2
N1.rightchild = N3
N2.leftchild = N4
N2.rightchild = N5
N3.leftchild = N6
N3.rightchild = N7
N4.leftchild = N8
N4.rightchild = N9
N5.leftchild = N10
N5.rightchild = N11

rootnode = N1


#N1.clone_to_normal(rootnode)
N1.left_cloned(rootnode)
print("---------")
#N1.preOrder(rootnode)
# Out:
# None
# N8
# N8
# None
# None
# N9
# N9
# None
# None
# N4
# N4
# None
# None
# N10
# N10
# None
# None
# N11
# N11
# None
# None
# N5
# N5
# None
# None
# N2
# N2
# None
# None
# N6
# N6
# None
# None
# N7
# N7
# None
# None
# N3
# N3
# None
# None
# N1
# N1
# None
# ---------

# %%
class BinaryTree:
    
    
    
    def __init__(self, data):
        self.data = data
        self.leftchild = None
        self.rightchild = None
        
        self.path = []
        
        
    def preOrder(self,root):
        if not root:
            return
    
        print(root.data)
        self.preOrder(root.leftchild)
        self.preOrder(root.rightchild)
    
    
    
    
    def postOrder(self, root):
        if not root:
            return
        
        self.postOrder(root.leftchild)
        self.postOrder(root.rightchild)
        print(root.data)
    
    
    
    def inOrder(self, root):
        if not root:
            return
    
    
        self.inOrder(root.leftchild)
        print(root.data)
        self.inOrder(root.rightchild)
        
        
    def search(self, inorder, start, end, curr):
        
        for i in range(start , end+1):
            if inorder[i] == curr:
                return i
            
        return -1 
        

    
    def count_single_child(self, root, parent):
        if root == None:
            return
        
        if (parent != None and parent.leftchild == root and parent.rightchild == None) :
            print(root.data)
            
        if (parent != None and parent.leftchild == None and parent.rightchild == root):
            print(root.data)
        
        
        
        l = self.count_single_child(root.leftchild, root)
        r = self.count_single_child(root.rightchild, root)
        
        
        
        

 
    
N1 = BinaryTree("N1")
N2 = BinaryTree("N2")
N3 = BinaryTree("N3")
N4 = BinaryTree("N4")
N5 = BinaryTree("N5")





N1.leftchild = N2
N1.rightchild = N3
N2.leftchild = N4
#N2.rightchild = N5


rootnode = N1

N1.count_single_child(N1, None)


# NONE IS THE PARENT OF ROOT
# Out:
# N4

# %%
class BinaryTree:
    
    
    
    def __init__(self, data):
        self.data = data
        self.leftchild = None
        self.rightchild = None
        
        self.path = []
        
        
    def preOrder(self,root):
        if not root:
            return
    
        print(root.data)
        self.preOrder(root.leftchild)
        self.preOrder(root.rightchild)
    
    
    
    
    def postOrder(self, root):
        if not root:
            return
        
        self.postOrder(root.leftchild)
        self.postOrder(root.rightchild)
        print(root.data)
    
    
    
    def inOrder(self, root):
        if not root:
            return
    
    
        self.inOrder(root.leftchild)
        print(root.data)
        self.inOrder(root.rightchild)
        
        
    def search(self, inorder, start, end, curr):
        
        for i in range(start , end+1):
            if inorder[i] == curr:
                return i
            
        return -1 
        

    
    def left_cloned(self, root):
        
        
        if root == None :
            return 
        
        l = BinaryTree(self.left_cloned(root.leftchild))
        r = BinaryTree(self.left_cloned(root.rightchild))
        
        
        copy = BinaryTree(root.data)
        root.leftchild = copy
        
        copy.leftchild = l
        root.rightchild = r
        
        
        self.inOrder(temp) 
        
        
    def clone_to_normal(self, root):
        if root == None:
            return None
        
        root.leftchild = root.leftchild.leftchild
        l = BinaryTree(self.clone_to_normal(root.leftchild))
        r = BinaryTree(self.clone_to_normal(root.rightchild))
        
        root.leftchild = l
        root.rightchild = r
        
        self.inOrder(root)
 
    
N1 = BinaryTree("N1")
N2 = BinaryTree("N1")
N3 = BinaryTree("N2")
N4 = BinaryTree("N2")
N5 = BinaryTree("N3")
N6 = BinaryTree("N4")
N7 = BinaryTree("N4")
N8 = BinaryTree("N5")
N9 = BinaryTree("N5")
N10 = BinaryTree("N6")
N11 = BinaryTree("N6")
N12 = BinaryTree(None)
N13 = BinaryTree(None)
N14 = BinaryTree(None)
N15 = BinaryTree(None)
N16 = BinaryTree(None)
N17 = BinaryTree(None)
N18 = BinaryTree(None)
N19 = BinaryTree(None)




N1.leftchild = N2
N1.rightchild = N3
N2.leftchild = N4
N2.rightchild = N5
N3.leftchild = N6
N3.rightchild = N7
N4.leftchild = N8
N4.rightchild = N9
N5.leftchild = N10
N5.rightchild = N11

N6.leftchild = N12
N6.rightchild = N12
N7.leftchild = N13
N7.rightchild = N14
N8.leftchild = N15
N8.rightchild = N16


rootnode = N1


N1.clone_to_normal(rootnode)
#N1.left_cloned(rootnode)
print("---------")
#N1.preOrder(rootnode)

## Just add some more None nodes andd it will work.

# %%
class BinaryTree:
    
    
    
    def __init__(self, data):
        self.data = data
        self.leftchild = None
        self.rightchild = None
        
        self.path = []
        
        
    def preOrder(self,root):
        if not root:
            return
    
        print(root.data)
        self.preOrder(root.leftchild)
        self.preOrder(root.rightchild)
    
    
    
    
    def postOrder(self, root):
        if not root:
            return
        
        self.postOrder(root.leftchild)
        self.postOrder(root.rightchild)
        print(root.data)
    
    
    
    def inOrder(self, root):
        if not root:
            return
    
    
        self.inOrder(root.leftchild)
        print(root.data)
        self.inOrder(root.rightchild)
        
        
    def search(self, inorder, start, end, curr):
        
        for i in range(start , end+1):
            if inorder[i] == curr:
                return i
            
        return -1 
        
        
    
    def countLeaves(self, root):
        if root == None:
            return 0
        if root.leftchild == None and root.rightchild == None:
            return 1
        
        l = self.countLeaves(root.leftchild)
        r = self.countLeaves(root.rightchild)
        
        return l + r
    
    
    def find_node(self, root, key):
        if root == None:
            return False
        
        if root.data == key:
            return True
        
        left = self.find_node(root.leftchild, key)
        if (left):
            return True
        
        right = self.find_node(root.rightchild, key)
        if (right):
            return True
        
        
        else:
            return False

        
    
    def find_node_path(self, root, key):
        if root == None:
            return False
        
        if root.data == key:
            self.path.append(root.data)
            
            return True , self.path
        
        left = self.find_node_path(root.leftchild, key)
        if (left):        #this means in ki left subtree mai mil gaya desired element (key). AB upar jayega vapis root tak
            self.path.append(root.data)
            
            return True , self.path
        
        right = self.find_node_path(root.rightchild, key)
        if (right):                                    #this means in ki left subtree mai mil gaya desired element (key)
            self.path.append(root.data)
            
            return True , self.path
        
        
        else:
            return False 
        
        
    
        

    
    
N1 = BinaryTree("N1")
N2 = BinaryTree("N2")
N3 = BinaryTree("N3")


N1.leftchild = N2
N1.rightchild = N3


N4 = BinaryTree("N4")
N5 = BinaryTree("N5")


N2.leftchild = N4
N2.rightchild = N5

rootnode = N1    

N1.find_node_path(N1, 'N3')
# Out:
# (True, ['N3', 'N1'])

# %%
class BinaryTree:
    
    
    
    def __init__(self, data):
        self.data = data
        self.leftchild = None
        self.rightchild = None
        
        self.path = []
        
        
    def preOrder(self,root):
        if not root:
            return
    
        print(root.data)
        self.preOrder(root.leftchild)
        self.preOrder(root.rightchild)
    
    
    
    
    def postOrder(self, root):
        if not root:
            return
        
        self.postOrder(root.leftchild)
        self.postOrder(root.rightchild)
        print(root.data)
    
    
    
    def inOrder(self, root):
        if not root:
            return
    
    
        self.inOrder(root.leftchild)
        print(root.data)
        self.inOrder(root.rightchild)
        
        
    def search(self, inorder, start, end, curr):
        
        for i in range(start , end+1):
            if inorder[i] == curr:
                return i
            
        return -1 
        

    
    def k_level(self, root, k, blocker):
        
        if root == None or k < 0 or root == blocker:
            return
        
        if k == 0:
            print(root.data)
        
        
        self.k_level(root.leftchild, k-1, blocker)
        self.k_level(root.rightchild , k-1, blocker)
        

        
    
    def find_node_path(self, root, key):
        if root == None:
            return False
        
        if root.data == key:
            self.path.append(root)
            
            return  self.path
        
        left = self.find_node_path(root.leftchild, key)
        if (left):
            self.path.append(root)
            
            return  self.path
        
        right = self.find_node_path(root.rightchild, key)
        if (right):
            self.path.append(root)
            
            return  self.path
        
        
        else:
            return False 
        
        
    def all_nodes_k(self, root, node, k, blocker):
        j = self.find_node_path(root , node)
        
        for i in range(len(j)):
            if i == 0:
                blocker = None
                
                self.k_level(j[i], k-i, blocker)
                
            else:
                self.k_level(j[i], k-i, j[i-1])
                
        #print(self.k_level(j[0], k))
        
        #print(j)
        #for i in j:
            #print(j.data)
            #self.k_level(j, k-1 )
        
        
        
        
        
    
        

    
    
N1 = BinaryTree("N1")
N2 = BinaryTree("N2")
N3 = BinaryTree("N3")


N1.leftchild = N2
N1.rightchild = N3


N4 = BinaryTree("N4")
N5 = BinaryTree("N5")

N6 = BinaryTree("N6")
N7 = BinaryTree("N7")

N8 = BinaryTree("N8")
N9 = BinaryTree("N9")

N10 = BinaryTree("N10")
N11 = BinaryTree("N11")


N2.leftchild = N4
N2.rightchild = N5

N3.leftchild = N6
N3.rightchild = N7

N4.leftchild = N8
N4.rightchild = N9

N5.leftchild = N10
N5.rightchild = N11

rootnode = N1    
blocker = BinaryTree("blocker")
N1.all_nodes_k(N1, 'N2', 2, blocker)
# Out:
# N8
# N9
# N10
# N11
# N3

# %%
N1 = BinaryTree("N1")
N2 = BinaryTree("N2")
N3 = BinaryTree("N3")


N1.leftchild = N2
N1.rightchild = N3


N4 = BinaryTree("N4")
N5 = BinaryTree("N5")


N2.leftchild = N4
N2.rightchild = N5

rootnode = N1

# %%
N1.count_nodes(N1)
# Out:
# 5

# %%
class Node:

    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

# %%
def buildTree(inOrder, preOrder, inStrt, inEnd):
    
    if (inStrt > inEnd):
        return None

    tNode = Node(preOrder[buildTree.preIndex])
    buildTree.preIndex += 1

    if inStrt == inEnd :
        return tNode
    inIndex = search(inOrder, inStrt, inEnd, tNode.data)
    tNode.left = buildTree(inOrder, preOrder, inStrt, inIndex-1)
    tNode.right = buildTree(inOrder, preOrder, inIndex + 1, inEnd)

    return tNode


def search(arr, start, end, value):
    for i in range(start, end + 1):
        if arr[i] == value:
            return i

def printInorder(node):
    if node is None:
        return

    printInorder(node.left)
    print(node.data)
    printInorder(node.right)

# %%
preOrder = [1,2,4,3,5]
inOrder = [4,2,1,5,3]



buildTree.preIndex = 0
root = buildTree(inOrder, preOrder, 0, len(inOrder)-1)



print("Inorder traversal of the constructed tree is")
printInorder(root)
# Out:
# Inorder traversal of the constructed tree is
# 4
# 2
# 1
# 5
# 3

# %%
class Node:

    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

# %%
def buildTree_po(inOrder, postOrder, inStrt, inEnd):
    
    if (inStrt > inEnd):
        return None

    tNode = Node(postOrder[buildTree_po.postIndex])
    buildTree_po.postIndex -= 1

    if inStrt == inEnd :
        return tNode
    inIndex = search(inOrder, inStrt, inEnd, tNode.data)
    
    
    tNode.right = buildTree_po(inOrder, postOrder, inIndex + 1, inEnd)
   

    tNode.left = buildTree_po(inOrder, postOrder, inStrt, inIndex-1)
    

    return tNode


def search(arr, start, end, value):
    for i in range(start, end + 1):
        if arr[i] == value:
            return i

def printInorder(node):
    if node is None:
        return

    printInorder(node.left)
    print(node.data)
    printInorder(node.right)

# %%
postOrder = [4,2,5,3,1]
inOrder = [4,2,1,5,3]



buildTree_po.postIndex = len(postOrder) - 1
root = buildTree_po(inOrder, postOrder, 0, len(inOrder)-1)



print("Inorder traversal of the constructed tree is")
printInorder(root)
# Out:
# Inorder traversal of the constructed tree is
# 4
# 2
# 1
# 5
# 3

# %%
class BinaryTree:
    
    
    
    def __init__(self, data):
        self.data = data
        self.leftchild = None
        self.rightchild = None
        
        
    def preOrder(self,root):
        if not root:
            return
    
        print(root.data)
        self.preOrder(root.leftchild)
        self.preOrder(root.rightchild)
    
    
    
    
    def postOrder(self, root):
        if not root:
            return
        
        self.postOrder(root.leftchild)
        self.postOrder(root.rightchild)
        print(root.data)
    
    
    
    def inOrder(self, root):
        if not root:
            return
    
    
        self.inOrder(root.leftchild)
        print(root.data)
        self.inOrder(root.rightchild)
        
        
    def search(self, inorder, start, end, curr):
        
        for i in range(start , end+1):
            if inorder[i] == curr:
                return i
            
        return -1 
        
        
    
    def countLeaves(self, root):
        if root == None:
            return 0
        if root.leftchild == None and root.rightchild == None:
            return 1
        
        l = self.countLeaves(root.leftchild)
        r = self.countLeaves(root.rightchild)
        
        return l + r
        
        

    
    
N1 = BinaryTree("N1")
N2 = BinaryTree("N2")
N3 = BinaryTree("N3")


N1.leftchild = N2
N1.rightchild = N3


N4 = BinaryTree("N4")
N5 = BinaryTree("N5")


N2.leftchild = N4
N2.rightchild = N5

rootnode = N1      
N1.countLeaves(N1)

# %%
# Out:
# 3
