# %%
class BST:
    def __init__(self, data):
        self.data = data
        self.leftchild = None
        self.rightchild = None
        
    def insertnode(self, rootnode, valuenode ):
        temp = rootnode
        if rootnode.data == None:
            rootnode.data = valuenode
        #return (rootnode.data)
        
        elif valuenode < rootnode.data :
            if rootnode.leftchild == None:
                rootnode.leftchild = BST(valuenode)
                
            else:
                self.insertnode(rootnode.leftchild, valuenode)
                
        else:
            if rootnode.rightchild == None:
                rootnode.rightchild = BST(valuenode)
                
            else:
                self.insertnode(rootnode.rightchild , valuenode )
                
        return rootnode.data #, self.pre_traverse(f)  #('done adding ... ')
    
    
    
    def pre_traverse(self, root):
        if root == None:
            return
        
        print(root.data)
        self.pre_traverse(root.leftchild)
        self.pre_traverse(root.rightchild)
        
            
        
            
            
            
n1 = BST(50)
n2.insertnode(n1 , 34)
n3.insertnode(n2 , 11)
n4.insertnode(n3 , 89)
n5.insertnode(n4 , 90)

#n1.insertnode(n1 , 100 , f)     
n1.pre_traverse(n1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-53d47272d8dc> in <module>
#      43
#      44 n1 = BST(50)
# ---> 45 n2.insertnode(n1 , 34)
#      46 n3.insertnode(n2 , 11)
#      47 n4.insertnode(n3 , 89)
#
# TypeError: insertnode() missing 1 required positional argument: 'f'

# %%
# Replace sum of larger in bst

# %%
class BST:
    def __init__(self, data):
        self.data = data
        self.leftchild = None
        self.rightchild = None
        self.sum =  0
        
    def insertnode(self, rootnode, valuenode):
        temp = rootnode
        if rootnode.data == None:
            rootnode.data = valuenode
        #return (rootnode.data)
        
        elif valuenode < rootnode.data :
            if rootnode.leftchild == None:
                rootnode.leftchild = BST(valuenode)
                
            else:
                self.insertnode(rootnode.leftchild, valuenode)
                
        else:
            if rootnode.rightchild == None:
                rootnode.rightchild = BST(valuenode)
                
            else:
                self.insertnode(rootnode.rightchild, valuenode)
                
        return rootnode.data 
    
    
    def sum_large(self, root):
        if root == None:
            return 
        
        self.sum_large(root.rightchild)
        od = root.data
        root.data = self.sum
        self.sum = self.sum + od
        
        self.sum_large(root.leftchild)
    
    
    def pre_traverse(self, root):
        if root == None:
            return
        
        print(root.data)
        self.pre_traverse(root.leftchild)
        self.pre_traverse(root.rightchild)
        
            
        
            
            
            
n1 = BST(50)
rootnode = n1
n1.insertnode(rootnode, 25)
n1.insertnode(rootnode, 75)
n1.insertnode(rootnode, 12)
n1.insertnode(rootnode, 37)
n1.insertnode(rootnode, 62)
n1.insertnode(rootnode, 87)
n1.insertnode(rootnode, 30)
n1.insertnode(rootnode, 40)
n1.insertnode(rootnode, 70)

n1.sum_large(rootnode)
rootnode.data
#n1.rightchild.data
#n1.pre_traverse(rootnode)
# Out:
# 294

# %%
#finding LCA

# %%
class BST:
    def __init__(self, data):
        self.data = data
        self.leftchild = None
        self.rightchild = None
        self.sum =  0
        self.path = []
        
        
    def insertnode(self, rootnode, valuenode):
        temp = rootnode
        if rootnode.data == None:
            rootnode.data = valuenode
        #return (rootnode.data)
        
        elif valuenode < rootnode.data :
            if rootnode.leftchild == None:
                rootnode.leftchild = BST(valuenode)
                
            else:
                self.insertnode(rootnode.leftchild, valuenode)
                
        else:
            if rootnode.rightchild == None:
                rootnode.rightchild = BST(valuenode)
                
            else:
                self.insertnode(rootnode.rightchild, valuenode)
                
        return rootnode.data 
    
    def path_node(self, root, key):
        if root == None:
            return False
        if root.data == key:
            self.path.append(root.data)
            return True, self.path
        
        l = self.path_node(root.leftchild , key)
        if (l):
            self.path.append(root.data)
            return True , self.path
            
        r = self.path_node(root.rightchild , key)
        if (r):
            self.path.append(root.data)
            return True,  self.path
        else:
            return False
        
    def LCA(self, root , key1 , key2):
        if root == None:
            return
        if key1 > root.data and key2 > root.data:
            return self.LCA(root.rightchild , key1 , key2)
        
        elif key1 < root.data and key2 < root.data:
            return self.LCA(root.lefttchild , key1 , key2)
        
        else:
            return root.data
        
    
    
    def range_in_bst(self, root, d1, d2):
        if root == None:
            return
        
        if d1 > root.data and d2 > root.data:
            return self.range_in_bst(root.leftchild , d1 , d2)
        
        elif d1 < root.data and d2 < root.data:
            return self.range_in_bst(root.rightchild , d1 , d2)
        
        else:
            self.range_in_bst(root.leftchild , d1 , d2)
            print(root.data)
            self.range_in_bst(root.rightchild , d1 , d2)
        
        
        
        
    def pre_traverse(self, root):
        if root == None:
            return
        
        print(root.data)
        self.pre_traverse(root.leftchild)
        self.pre_traverse(root.rightchild)
        
            
        
            
            
            
n1 = BST(50)
rootnode = n1
n1.insertnode(rootnode, 25)
n1.insertnode(rootnode, 75)
n1.insertnode(rootnode, 12)
n1.insertnode(rootnode, 37)
n1.insertnode(rootnode, 62)
n1.insertnode(rootnode, 87)
n1.insertnode(rootnode, 30)
n1.insertnode(rootnode, 40)
n1.insertnode(rootnode, 70)

#n1.path_node(rootnode , 30)

#n1.LCA(rootnode , 30 , 62)
n1.range_in_bst(rootnode , 13 , 90)
#n1.rightchild.data
#n1.pre_traverse(rootnode)
# Out:
# 25
# 30
# 37
# 40
# 50
# 62
# 70
# 75
# 87

# %%
# remove a node form BST

# %%
class BST:
    def __init__(self, data):
        self.data = data
        self.leftchild = None
        self.rightchild = None
        
    def insertnode(self, rootnode, valuenode):
        
        if rootnode.data == None:
            rootnode.data = valuenode
        #return (rootnode.data)
        
        elif valuenode < rootnode.data :
            if rootnode.leftchild == None:
                rootnode.leftchild = BST(valuenode)
                
            else:
                self.insertnode(rootnode.leftchild, valuenode)
                
        else:
            if rootnode.rightchild == None:
                rootnode.rightchild = BST(valuenode)
                
            else:
                self.insertnode(rootnode.rightchild, valuenode)
                
        return rootnode.data
    
    
    def maxi(self, root):
        
        if root.rightchild == None:
            return root.data
        
        if root.rightchild != None:
            return self.maxi(root.rightchild)
        
        
    def delete_node(self, rootnode, valuenode):
        
        if rootnode == None:
            return None
        
        # case when the valuenode is a leaf
        if valuenode > rootnode.data:
            rootnode.rightchild = self.delete_node(rootnode.rightchild , valuenode)
        
        
        if valuenode < rootnode.data:
            rootnode.leftchild = self.delete_node(rootnode.leftchild , valuenode)
            
            
        else:
            if rootnode.data == valuenode and (rootnode.leftchild != None and rootnode.rightchild != None):
                maxx = self.maxi(rootnode.leftchild)
                return maxx 
            
        
            
        
            #if the value node has only one child
            elif rootnode.data == valuenode and  (rootnode.leftchild != None) :
                return rootnode.leftchild
            
            elif rootnode.data == valuenode and (rootnode.rightchild != None):
                return rootnode.rightchild
            else:
                return None
            
            
        return rootnode
        
        
    
    
    def pre_traverse(self, root):
        if root == None:
            return
        
        print(root.data)
        self.pre_traverse(root.leftchild)
        self.pre_traverse(root.rightchild)
        
            
        
            
            
            
n1 = BST(50)
rootnode = n1
n1.insertnode(rootnode, 25)
n1.insertnode(rootnode, 75)
n1.insertnode(rootnode, 12)
n1.insertnode(rootnode, 37)
n1.insertnode(rootnode, 62)
n1.insertnode(rootnode, 87)
n1.insertnode(rootnode, 30)
n1.insertnode(rootnode, 40)
n1.insertnode(rootnode, 70)


n1.delete_node(n1, 62)

#n1.maxi(n1)

# %%
n1.pre_traverse(rootnode)
# Out:
# 50
# 25
# 12
# 37
# 30
# 40
# 75
# 70
# 87
