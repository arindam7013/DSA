# %%
#**** IMPORTANT ****     C195 sum 
class BinaryTree:
    
    
    
    def __init__(self, data):
        self.data = data
        self.leftchild = None
        self.rightchild = None

# %%
#c 179  Height of a tree
class BinaryTree:
    
    
    
    def __init__(self, data):
        self.data = data
        self.leftchild = None
        self.rightchild = None

        
        
        
    def preorder_iter(self, root):
        
        if root == None:
            return 0
        
        left = self.height(root.leftchild)
        right = self.height(root.rightchild)
        if left > right:
            return left + 1
        else:
            return right + 1
        

N1 = BinaryTree("N1")
N2 = BinaryTree("N2")
N3 = BinaryTree("N3")


N1.leftchild = N2
N1.rightchild = N3


N4 = BinaryTree("N4")
N5 = BinaryTree("N5")


N2.leftchild = N4
N2.rightchild = N5

rootnode = N1
N1.height(N1)

# %%
# Find root to node path

# %%
# Definition for a  binary tree node
# class TreeNode:
#    def __init__(self, x):
#        self.val = x
#        self.left = None
#        self.right = None

class Solution:
    

        
    # @param A : root node of tree
    # @param B : integer
    # @return a list of integers
    def solve(self, A, B):
        
        return self.find(A,B, [])
        #print(gg)


    def find(self, A, B, path):
        
        if A == None:
            return None

        if A.val == B:
            return path + [A.val]
            #return True

        l = self.find(A.left, B, path + [A.val])
        if (l):
            return l
        r = self.find(A.right, B ,  path + [A.val])
        if (r):
            return r

        else:
            return None

# %%
# Python program to find the nodes at k distance from root

# A Binary tree node
class Node:
	
	# Constructor to create a new node
	def __init__(self, data):
		self.data = data
		self.left = None
		self.right = None

def printKDistant(root, k):
	
	if root is None:
		return
	if k == 0:
		print root.data,
	else:
		printKDistant(root.left, k-1)
		printKDistant(root.right, k-1)

# Driver program to test above function
"""
Constructed binary tree is
			1
		/ \
		2	 3
	/ \ /
	4	 5 8
"""
root = Node(1)
root.left = Node(2)
root.right = Node(3)
root.left.left = Node(4)
root.left.right = Node(5)
root.right.left = Node(8)

printKDistant(root, 2)

# This code is contributed by Nikhil Kumar Singh(nickzuck_007)

# %%
        
def inOrder_sum( root):
        
        if root is not None:
           inOrder_sum(root.leftchild)
           
           print ("root at-> ", root.data , end = ' ')
           inOrder_sum(root.rightchild)
        

        

    
def toSumTree(root) :
     
    # Base case
    if (root == None) :
        return 0
    #print(root.data)

    #old_val = root.data
 
    while root.leftchild != None or root.rightchild != None:
        root.data = toSumTree(root.leftchild.data) + toSumTree(root.rightchild.data)

    return root.data + 1 #+ old_val
 
    

  

    
N1 = BinaryTree(1)
N2 = BinaryTree(2)
N3 = BinaryTree(3)


N1.leftchild = N2
N1.rightchild = N3


N4 = BinaryTree("N4")
N5 = BinaryTree("N5")


#N2.leftchild = N4
#N2.rightchild = N5

rootnode = N1

toSumTree(rootnode)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-c3b9d30b66dd> in <module>
#      48 rootnode = N1
#      49
# ---> 50 toSumTree(rootnode)
#      51
#      52
#
# <ipython-input-22-c3b9d30b66dd> in toSumTree(root)
#      21
#      22     while root.leftchild != None or root.rightchild != None:
# ---> 23         root.data = toSumTree(root.leftchild.data) + toSumTree(root.rightchild.data)
#      24
#      25     return root.data + 1 #+ old_val
#
# <ipython-input-22-c3b9d30b66dd> in toSumTree(root)
#      20     #old_val = root.data
#      21
# ---> 22     while root.leftchild != None or root.rightchild != None:
#      23         root.data = toSumTree(root.leftchild.data) + toSumTree(root.rightchild.data)
#      24
#
# AttributeError: 'int' object has no attribute 'leftchild'

# %%
#c Traverse using iteration
class BinaryTree:
    
    
    
    def __init__(self, data):
        self.data = data
        self.leftchild = None
        self.rightchild = None

        
        
        
    def InOrder(self, root):
        
        
        
        stack = []
        curr = root
        while stack or curr:
            if curr :
                stack.append(curr)
                curr = curr.leftchild
                
            else:
                curr = stack.pop()
                print(curr.data)
                curr = curr.rightchild
                
                
    def PreOrder(self, root):
        if root == None:
            return
        
        
        
        stack = []
        curr = root
        stack.append(curr)
        
        while len(stack) > 0:
            nd = stack.pop()
            print(nd.data)
                
            if nd.rightchild != None:
                stack.append(nd.rightchild)
            
            
            if nd.leftchild != None:
                stack.append(nd.leftchild)
                
                
                

                
    

N1 = BinaryTree("N1")
N2 = BinaryTree("N2")
N3 = BinaryTree("N3")


N1.leftchild = N2
N1.rightchild = N3


N4 = BinaryTree("N4")
N5 = BinaryTree("N5")


N2.leftchild = N4
N2.rightchild = N5

rootnode = N1
#N1.InOrder(rootnode)
N1.PreOrder(rootnode)
# Out:
# N1
# N2
# N4
# N5
# N3

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-ae404a54e3c0> in <module>
#      17 rootnode = N1
#      18
# ---> 19 toSumTree(rootnode)
#      20
#
# <ipython-input-2-52d940c1f6e0> in toSumTree(root)
#      21
#      22     while root.leftchild != None or root.rightchild != None:
# ---> 23         root.data = toSumTree(root.leftchild.data) + toSumTree(root.rightchild.data)
#      24
#      25     return root.data + 1 #+ old_val
#
# <ipython-input-2-52d940c1f6e0> in toSumTree(root)
#      20     #old_val = root.data
#      21
# ---> 22     while root.leftchild != None or root.rightchild != None:
#      23         root.data = toSumTree(root.leftchild.data) + toSumTree(root.rightchild.data)
#      24
#
# AttributeError: 'int' object has no attribute 'leftchild'

# %%
rootnode.leftchild.data
# Out:
# 2

# %%
toSumTree(rootnode)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-198-605ee272364f> in <module>
# ----> 1 toSumTree(rootnode)
#
# <ipython-input-195-30a587813518> in toSumTree(root)
#      21
#      22     while root.leftchild != None or root.rightchild != None:
# ---> 23         root.data = toSumTree(root.leftchild.data) + toSumTree(root.rightchild.data)
#      24
#      25     return root.data #+ old_val
#
# <ipython-input-195-30a587813518> in toSumTree(root)
#      20     #old_val = root.data
#      21
# ---> 22     while root.leftchild != None or root.rightchild != None:
#      23         root.data = toSumTree(root.leftchild.data) + toSumTree(root.rightchild.data)
#      24
#
# AttributeError: 'int' object has no attribute 'leftchild'

# %%
inOrder_sum(rootnode)

# %%
#c 185 and 186     #Left and right view of tree
def right_view(self, root):
        self.root = root
        q = [root, None]
        level = 0
        sum = 0
        print(root.data)
        while len(q) != 0:
            p = q.pop(0)
  
            
            
            if p == None and len(q) > 0:
                print(q[-1].data)
                q.append(None)
                
                continue   
            else:
                
                
                temp = p
                
                if temp is not None:
                    #print(p.data)
                    if temp.leftchild is not None:
                        q.append(temp.leftchild)
                    if p.rightchild is not None:
                        q.append(temp.rightchild)
                        
                        
                        
    def left_view(self, root):
        self.root = root
        q = [root, None]
        level = 0
        sum = 0
        print(root.data)
        while len(q) != 0:
            p = q.pop(0)
  
            
            
            if p == None and len(q) > 0:
                print(q[0].data)
                q.append(None)
                
                continue   
            else:
                
                
                temp = p
                
                if temp is not None:
                    #print(p.data)
                    if temp.leftchild is not None:
                        q.append(temp.leftchild)
                    if p.rightchild is not None:
                        q.append(temp.rightchild)

# %%
#c 179  Height of a tree
class BinaryTree:
    
    
    
    def __init__(self, data):
        self.data = data
        self.leftchild = None
        self.rightchild = None

        
        
        
    def height(self, root):
        
        if root == None:
            return 0
        
        left = self.height(root.leftchild)
        right = self.height(root.rightchild)
        if left > right:
            return left + 1
        else:
            return right + 1
        

N1 = BinaryTree("N1")
N2 = BinaryTree("N2")
N3 = BinaryTree("N3")


N1.leftchild = N2
N1.rightchild = N3


N4 = BinaryTree("N4")
N5 = BinaryTree("N5")


N2.leftchild = N4
N2.rightchild = N5

rootnode = N1
N1.height(N1)

# %%
#c 177 level order traversal
class BinaryTree:
    
    
    
    def __init__(self, data):
        self.data = data
        self.leftchild = None
        self.rightchild = None
        
        

        
        
        
    def level_order(self, root):
        
        if root == None:
            return
        q = []
        q.append(root)
        
        
        while len(q) != 0:
            p = q.pop(0)
            print(p.data)
            
            
            if p.leftchild is not None:
                q.append(p.leftchild)
                
                
                
            if p.rightchild != None:
                q.append(p.rightchild)
                
                

                
        
        
    def search(self, inorder, start, end, curr):
        
        for i in range(start , end+1):
            if inorder[i] == curr:
                return i
            
        return -1 
        
        
    
        
        

N1 = BinaryTree("N1")
N2 = BinaryTree("N2")
N3 = BinaryTree("N3")


N1.leftchild = N2
N1.rightchild = N3


N4 = BinaryTree("N4")
N5 = BinaryTree("N5")


N2.leftchild = N4
N2.rightchild = N5

rootnode = N1
N1.level_order(N1)
# Out:
# N1
# N2
# N3
# N4
# N5

# %%
#c 179  Height of a tree
class BinaryTree:
    
    
    
    def __init__(self, data):
        self.data = data
        self.leftchild = None
        self.rightchild = None

        
        
        
    def height(self, root):
        
        if root == None:
            return 0
        
        
        
        left = self.height(root.leftchild)
        right = self.height(root.rightchild)
        if left > right:
            return left + 1
        else:
            return right + 1
        
        
        
        
        
        
    def diameter(self, root):
        if root == None:
            return 0
        
        lefth = self.height(root.leftchild)
        righth = self.height(root.rightchild)
        
        dia = lefth + righth + 1
        leftd = self.diameter(rootnode.leftchild)
        rightd = self.diameter(rootnode.rightchild)
        
        if dia > leftd and dia > rightd:
            return dia
        elif leftd > rightd and leftd > dia:
            return leftd
        else:
            return rightd
        
  

    

N1 = BinaryTree("N1")
N2 = BinaryTree("N2")
N3 = BinaryTree("N3")


N1.leftchild = N2
N1.rightchild = N3


N4 = BinaryTree("N4")
N5 = BinaryTree("N5")


N2.leftchild = N4
N2.rightchild = N5

rootnode = N1
N1.diameter(rootnode)
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-22-3522dc1597a3> in <module>
#      70
#      71 rootnode = N1
# ---> 72 N1.diameter(rootnode)
#      73
#      74
#
# <ipython-input-22-3522dc1597a3> in diameter(self, root)
#      39
#      40         dia = lefth + righth + 1
# ---> 41         leftd = self.diameter(rootnode.leftchild)
#      42         rightd = self.diameter(rootnode.rightchild)
#      43
#
# ... last 1 frames repeated, from the frame below ...
#
# <ipython-input-22-3522dc1597a3> in diameter(self, root)
#      39
#      40         dia = lefth + righth + 1
# ---> 41         leftd = self.diameter(rootnode.leftchild)
#      42         rightd = self.diameter(rootnode.rightchild)
#      43
#
# RecursionError: maximum recursion depth exceeded in comparison

# %%
#c 179  Mirror of a tree
class BinaryTree:
    
    
    
    def __init__(self, data):
        self.data = data
        self.leftchild = None
        self.rightchild = None

        
def inOrder( root):
        if root is not None:
           inOrder(root.leftchild)
           print (root.data, end = ' ')
           inOrder(root.rightchild)
        
        
        
def mirror( root):
        temp = root
        if temp == None:
            return root
        mirror(temp.rightchild)
        mirror(temp.leftchild)
        
        temp.leftchild , temp.rightchild = temp.rightchild, temp.leftchild
        
        
        
        

        
        
def level_order(self, root):
        
        if root == None:
            return
        q = []
        q.append(root)
        
        
        while len(q) != 0:
            p = q.pop(0)
            print(p.data)
            
            
            if p.leftchild is not None:
                q.append(p.leftchild)
                
                
                
            if p.rightchild != None:
                q.append(p.rightchild)
        

  

    

N1 = BinaryTree("N5")
N2 = BinaryTree("N3")
N3 = BinaryTree("N6")


N1.leftchild = N2
N1.rightchild = N3


N4 = BinaryTree("N2")
N5 = BinaryTree("N4")


N2.leftchild = N4
N2.rightchild = N5

rootnode = N1
mirror(rootnode)
inOrder(rootnode)
