# %%
#c 145 Remove Duplicates in an unsorted Linked List.

class linkednode:
    def __init__(self , data):
        self.data = data
        self.nextnode = None
        self.previousnode = None
        
    def insert(self, head, where, key):
        self.head = head
        self.where = where
        self.key = key
        
        while head is not where:
            head = head.nextnode
        print("pointer and data here ->" , head.data)
        temp = head.nextnode
        #print("next node and data of head and pointer ->", temp.data)
        head.nextnode = key
        key.nextnode = temp
        
        
    def remove_duplicate_unsorted(self, head):
        self.head = head
        ptr = head
        if ptr == None:
            return
        temp = []
        temp.append(ptr.data)
        while ptr.nextnode != None:
            if ptr.nextnode.data not in temp:
                temp.append(ptr.nextnode.data)
                ptr = ptr.nextnode
                
            else:
                ptr.nextnode = ptr.nextnode.nextnode

                
                
                
        return self.traverse(head)
            
            


    def traverse(self, head):
        self.head = head
        
        while head is not None:
            print( head.data, "->" ,end ='')
            head = head.nextnode

a = linkednode(6)
b = linkednode(2)
c = linkednode(3)
d = linkednode(3)
e = linkednode(5)
f = linkednode(6)

a.nextnode = b
b.nextnode = c
c.nextnode = d
d.nextnode = e
e.nextnode = f
f.nextnode = None
head = a
a.remove_duplicate_unsorted(head)
# Out:
# 6 ->2 ->3 ->5 ->

# %%
# Out:
# 3

# %%
a = [2,3,4]

# %%
print(a)
# Out:
# [2, 3, 4]

# %%
#c 141 and 142 and 143  Write a program to Detect loop in a linked list and delete the loop. Detect the starting point of Loop

class linkednode:
    def __init__(self , data):
        self.data = data
        self.nextnode = None
        self.previousnode = None
        
    def insert(self, head, where, key):
        self.head = head
        self.where = where
        self.key = key
        
        while head is not where:
            head = head.nextnode
        print("pointer and data here ->" , head.data)
        temp = head.nextnode
        #print("next node and data of head and pointer ->", temp.data)
        head.nextnode = key
        key.nextnode = temp
        
        
    def loop_detect(self, head):
        self.head = head
        tort = head
        hare = head
        while  hare!= None and hare.nextnode != None:
            tort = tort.nextnode
            hare = hare.nextnode.nextnode
            
            if hare == tort:
                return True
                break
        else:
            return False
        
        
    def loop_start_point(self, head):
        self.head = head
        tort = head
        hare = head
        while  hare!= None and hare.nextnode != None:
            hare = hare.nextnode.nextnode
            tort = tort.nextnode
            
            
            if hare == tort:
                hare = head
                while hare.nextnode != tort.nextnode:
                    tort = tort.nextnode 
                    hare = hare.nextnode
                
                return hare.nextnode.data
                break
                
                
        
    def loop_remove(self, head):
        self.head = head
        tort = head
        hare = head
        while  hare!= None and hare.nextnode != None:
            hare = hare.nextnode.nextnode
            tort = tort.nextnode
            
            
            if hare == tort:
                hare = head
                while hare.nextnode != tort.nextnode:
                    tort = tort.nextnode 
                    hare = hare.nextnode
                tort.nextnode = None
                return 1
                break
                
                

            
    def traverse_rec(self, head):
        if head == None or head.nextnode == None:
            return head
        
        newhead = self.traverse_rec(head.nextnode)
        head.nextnode.nextnode = head
        head.nextnode = None
        
        
        return newhead

    def traverse(self, head):
        self.head = head
        
        while head is not None:
            print( head.data, "->" ,end ='')
            head = head.nextnode

a = linkednode('A')
b = linkednode('B')
c = linkednode('C')
d = linkednode('D')
e = linkednode('E')
f = linkednode('F')

a.nextnode = b
b.nextnode = c
c.nextnode = d
d.nextnode = e
e.nextnode = f
f.nextnode = d
head = a

a.loop_start_point(head)
#a.traverse(head)
# Out:
# 'D'

# %%
#c 144 Remove Duplicates in a sorted Linked List.

class linkednode:
    def __init__(self , data):
        self.data = data
        self.nextnode = None
        self.previousnode = None
        
    def insert(self, head, where, key):
        self.head = head
        self.where = where
        self.key = key
        
        while head is not where:
            head = head.nextnode
        print("pointer and data here ->" , head.data)
        temp = head.nextnode
        #print("next node and data of head and pointer ->", temp.data)
        head.nextnode = key
        key.nextnode = temp
        
        
    def remove_duplicate(self, head):
        self.head = head
        ptr = head
        if ptr == None:
            return
        while ptr.nextnode != None:
            if ptr.data == ptr.nextnode.data:
                new = ptr.nextnode.nextnode
                ptr.nextnode = None
                ptr.nextnode = new
            else:
                ptr = ptr.nextnode
                
                
                
        return self.traverse(head)
            
            


    def traverse(self, head):
        self.head = head
        
        while head is not None:
            print( head.data, "->" ,end ='')
            head = head.nextnode

a = linkednode(2)
b = linkednode(2)
c = linkednode(3)
d = linkednode(3)
e = linkednode(5)
f = linkednode(6)

a.nextnode = b
b.nextnode = c
c.nextnode = d
d.nextnode = e
e.nextnode = f
f.nextnode = None
head = a
a.remove_duplicate(head)

# %%
#c 144 Remove Duplicates in a sorted Linked List.

class linkednode:
    def __init__(self , data):
        self.data = 0
        self.nextnode = None
        self.previousnode = None
        
    def insert(self, head, where, key):
        self.head = head
        self.where = where
        self.key = key
        
        while head is not where:
            head = head.nextnode
        print("pointer and data here ->" , head.data)
        temp = head.nextnode
        #print("next node and data of head and pointer ->", temp.data)
        head.nextnode = key
        key.nextnode = temp
        
        
    def remove_duplicate(self, head1, head2):
        self.head = head
        ptr1 = head1
        ptr2 = head2
        dummy = linkednode()
        tail = dummy
        if ptr1 == None:
            return ptr2
        if ptr2 == None:
            return ptr1
        while ptr1.nextnode != None or ptr2.nextnode != None:
            
            if ptr1.data == ptr2.data:
                tail.nextnode = ptr1
                ptr1 = ptr1.nextnode
                ptr2 = ptr2.nextnode
            
            else:
                if ptr2.data > ptr1.data:
                    ptr1 = ptr1.nextnode
                else:
                    ptr2 = ptr2.nextnode
                

                
                
                
        return self.traverse(dummy)
            
            


    def traverse(self, head):
        self.head = head
        
        while head is not None:
            print( head.data, "->" ,end ='')
            head = head.nextnode

a = linkednode(2)
b = linkednode(2)
c = linkednode(3)
d = linkednode(3)
e = linkednode(5)
f = linkednode(6)

a.nextnode = b
b.nextnode = c
c.nextnode = d
d.nextnode = e
e.nextnode = f
f.nextnode = None




g = linkednode(2)
h = linkednode(3)
i = linkednode(4)
j = linkednode(5)
k = linkednode(5)
l = linkednode(6)

g.nextnode = h
h.nextnode = i
i.nextnode = j
j.nextnode = k
k.nextnode = l
l.nextnode = None







head1 = a
head2 = g
a.remove_duplicate(head1 , head2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-623f9e513141> in <module>
#      99 head1 = a
#     100 head2 = g
# --> 101 a.remove_duplicate(head1 , head2)
#
# <ipython-input-19-623f9e513141> in remove_duplicate(self, head1, head2)
#      25         ptr1 = head1
#      26         ptr2 = head2
# ---> 27         dummy = linkednode()
#      28         tail = dummy
#      29         if ptr1 == None:
#
# TypeError: __init__() missing 1 required positional argument: 'data'

# %%
Middle of a LinkedList
Method 1: 
Traverse the whole linked list and count the no. of nodes. Now traverse the list again till count/2 and return the node at count/2. 

Method 2: 
Traverse linked list using two pointers. Move one pointer by one and the other pointers by two. When the fast pointer reaches the end slow pointer will reach the middle of the linked list.
