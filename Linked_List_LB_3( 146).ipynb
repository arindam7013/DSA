# %%
#c 147       

class linkednode:
    def __init__(self , data):
        self.data = data
        self.nextnode = None
        self.previousnode = None
        
    def insert(self, head, where, key):
        self.head = head
        self.where = where
        self.key = key
        
        while head is not where:
            head = head.nextnode
        print("pointer and data here ->" , head.data)
        temp = head.nextnode
        #print("next node and data of head and pointer ->", temp.data)
        head.nextnode = key
        key.nextnode = temp
        
    def add_one(self, head):
        self.head= head
        
        temp = head
        if temp.nextnode == None:
            temp.data = temp.data + 1
            return temp
        
        tempp = self.traverse_iter(head)
        sum = 0
        carry = 1
        #tempp = head
        
        while tempp.nextnode != None:
            
            if (tempp.data + carry) % 10 == 0:
                tempp.data = 0
                sum = 0
            else:
                sum = tempp.data + carry
                carry = 0
                tempp.data = sum
                sum = 0
        self.traverse_iter(head)
        
        
                
        
        
                
            
    def traverse_iter(self,head):
        
        if head == None:
            return None
        prev = None
        curr = head
        
        while curr != None:
            next = curr.nextnode
            curr.nextnode = prev
            
            prev = curr
            curr = next
            head = prev
            
           
        return self.traverse(head)       
            
            
            
    def traverse(self, head):
        self.head = head
        temp = head
        
        while temp is not None:
            print( temp.data, "->" ,end ='')
            temp = temp.nextnode
        return head

a = linkednode(6)
b = linkednode(2)
c = linkednode(3)
d = linkednode(3)
e = linkednode(5)
f = linkednode(9)

a.nextnode = b
b.nextnode = c
c.nextnode = d
d.nextnode = e
e.nextnode = f
f.nextnode = None
head = a
a.add_one(head)
# Out:
# 9 ->5 ->3 ->3 ->2 ->6 ->
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-a180390a9081> in <module>
#      94 f.nextnode = None
#      95 head = a
# ---> 96 a.add_one(head)
#
# <ipython-input-5-a180390a9081> in add_one(self, head)
#      39                 sum = 0
#      40             else:
# ---> 41                 sum = tempp.data + carry
#      42                 carry = 0
#      43                 tempp.data = sum
#
# KeyboardInterrupt:

# %%
#c 146       Write a Program to Move the last element to Front in a Linked List.

class linkednode:
    def __init__(self , data):
        self.data = data
        self.nextnode = None
        self.previousnode = None
        
    def insert(self, head, where, key):
        self.head = head
        self.where = where
        self.key = key
        
        while head is not where:
            head = head.nextnode
        print("pointer and data here ->" , head.data)
        temp = head.nextnode
        #print("next node and data of head and pointer ->", temp.data)
        head.nextnode = key
        key.nextnode = temp
        
    def last_to_first(self, head):
        self.head = head
        ptr = head
        key = ptr
        
        if ptr.nextnode == None:
            return ptr
            
        
        while ptr and ptr.nextnode :
            sec_last = ptr
            ptr = ptr.nextnode
            
        sec_last.nextnode = None
        ptr.nextnode = head
        head = ptr
        
        return self.traverse(head)
            
            
            
    def traverse(self, head):
        self.head = head
        
        while head is not None:
            print( head.data, "->" ,end ='')
            head = head.nextnode

a = linkednode(6)
b = linkednode(2)
c = linkednode(3)
d = linkednode(3)
e = linkednode(5)
f = linkednode(9)

a.nextnode = b
b.nextnode = c
c.nextnode = d
d.nextnode = e
e.nextnode = f
f.nextnode = None
head = a
a.last_to_first(head)
