# %%
class linkednode:
    def __init__(self , data):
        self.data = data
        self.nextnode = None
        self.previousnode = None
        
    def insert(self, head, where, key):
        self.head = head
        self.where = where
        self.key = key
        
        while head is not where:
            head = head.nextnode
        print("pointer and data here ->" , head.data)
        temp = head.nextnode
        #print("next node and data of head and pointer ->", temp.data)
        head.nextnode = key
        key.nextnode = temp
        
        
        
    def reverse_k(self, head, k):
        if head == None or head.nextnode == None:
            return head
        count = 0
        curr = head
        prev = None
        while curr != None and count < k:
            next = curr.nextnode
            curr.nextnode = prev
            prev = curr
            curr = next
            count = count + 1
        if next != None:
            head.nextnode = self.reverse_k(next, k)
            
        return prev
        
        

        
    def traverse_rec(self, head):
        if head == None or head.nextnode == None:
            return head
        
        newhead = self.traverse_rec(head.nextnode)
        head.nextnode.nextnode = head
        head.nextnode = None
        
        
        return newhead

    def traverse(self, head):
        self.head = head
        
        while head is not None:
            print( head.data, "->" ,end ='')
            head = head.nextnode

a = linkednode('A')
b = linkednode('B')
c = linkednode('C')
d = linkednode('D')
e = linkednode('E')
f = linkednode('F')

a.nextnode = b
b.nextnode = c
c.nextnode = d
d.nextnode = None
head = a
a.traverse(a.reverse_k(head, 3))

# %%
a = linkednode('A')
b = linkednode('B')
c = linkednode('C')
d = linkednode('D')
e = linkednode('E')
f = linkednode('F')

a.nextnode = b
b.nextnode = c
c.nextnode = d
d.nextnode = None
head = a
a.traverse(a.reverse_k(head, 3))

# %%
# Out:
# C ->B ->A ->D ->

# %%
#c 139     Write a Program to reverse the Linked List. (Both Iterative and recursive)

class linkednode:
    def __init__(self , data):
        self.data = data
        self.nextnode = None
        self.previousnode = None
        
    def insert(self, head, where, key):
        self.head = head
        self.where = where
        self.key = key
        
        while head is not where:
            head = head.nextnode
        print("pointer and data here ->" , head.data)
        temp = head.nextnode
        #print("next node and data of head and pointer ->", temp.data)
        head.nextnode = key
        key.nextnode = temp
        
    def traverse_iter(self,head):
        
        if head == None:
            return None
        prev = None
        curr = head
        
        while curr != None:
            next = curr.nextnode
            curr.nextnode = prev
            
            prev = curr
            curr = next
            head = prev
            
           
        self.traverse(head)
        
        
        
    def traverse_rec(self, head):
        if head == None or head.nextnode == None:
            return head
        
        newhead = self.traverse_rec(head.nextnode)
        head.nextnode.nextnode = head
        head.nextnode = None
        
        return newhead

    def traverse(self, head):
        self.head = head
        
        while head is not None:
            print( head.data, "->" ,end ='')
            head = head.nextnode
        

        
a = linkednode('A')
b = linkednode('B')
c = linkednode('C')
d = linkednode('D')
e = linkednode('E')
f = linkednode('F')

a.nextnode = b
b.nextnode = c
c.nextnode = d
d.nextnode = None
head = a        

a.traverse(a.traverse_rec(head))
#a.traverse(a.traverse_iter(head))
# Out:
# D ->C ->B ->A ->

# %%
class linkednode:
    def __init__(self , data):
        self.data = data
        self.nextnode = None
        self.previousnode = None
        
    def insert(self, head, where, key):
        self.head = head
        self.where = where
        self.key = key
        
        while head is not where:
            head = head.nextnode
        print("pointer and data here ->" , head.data)
        temp = head.nextnode
        #print("next node and data of head and pointer ->", temp.data)
        head.nextnode = key
        key.nextnode = temp
        

        
    def traverse(self, head):
        self.head = head
        while head is not None:
            print( head.data, "->" ,end ='')
            head = head.nextnode

# %%
# C 140 Reverse K nodes


class linkednode:
    def __init__(self , data):
        self.data = data
        self.nextnode = None
        self.previousnode = None
        
    def insert(self, head, where, key):
        self.head = head
        self.where = where
        self.key = key
        
        while head is not where:
            head = head.nextnode
        print("pointer and data here ->" , head.data)
        temp = head.nextnode
        #print("next node and data of head and pointer ->", temp.data)
        head.nextnode = key
        key.nextnode = temp
        
        
        
    def reverse_k(self, head, k):
        if head == None or head.nextnode == None:
            return head
        count = 0
        curr = head
        prev = None
        while curr != None and count < k:
            next = curr.nextnode
            curr.nextnode = prev
            prev = curr
            curr = next
            count = count + 1
        if next != None:
            head.nextnode = self.reverse_k(next, k)
            
        return prev
        
        

        
    def traverse_rec(self, head):
        if head == None or head.nextnode == None:
            return head
        
        newhead = self.traverse_rec(head.nextnode)
        head.nextnode.nextnode = head
        head.nextnode = None
        
        
        return newhead

    def traverse(self, head):
        self.head = head
        
        while head is not None:
            print( head.data, "->" ,end ='')
            head = head.nextnode

a = linkednode('A')
b = linkednode('B')
c = linkednode('C')
d = linkednode('D')
e = linkednode('E')
f = linkednode('F')

a.nextnode = b
b.nextnode = c
c.nextnode = d
d.nextnode = None
head = a
a.traverse(a.reverse_k(head, 3))
# Out:
# C ->B ->A ->D ->
