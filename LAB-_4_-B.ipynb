# %%
import pandas as pd
import numpy as np
from sklearn import linear_model

# %%
import os
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(os.getcwd()+'\\Datasets\\car data.csv')
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['Year','Kms_Driven','Present_Price']],df['Selling_Price'])
# Out:
# LinearRegression()

# %%
# y = b0 + b1*Year + b2*Kms_Driven + b3*Present_Price 

reg.coef_  
# values of b1, b2, b3
# Out:
# array([ 4.81304272e-01, -1.21350189e-06,  5.25621901e-01])

# %%
reg.intercept_
# value of b0
# Out:
# -968.4712735481945

# %%
reg.predict([[2019, 5200, 4.15]])
# Out:
# array([5.45707135])

# %% [markdown]
# # Gradient Descent Implementation

# %%
def gradient_descent(x,y):
    slope = intercept = 0
    iterations = 1000
    n = len(x)
    learning_rate = 0.001

    for i in range(iterations):
        y_predicted = slope * x + intercept
        cost = (1/n) * sum([val**2 for val in (y-y_predicted)])
        m = -(2/n)*sum(x*(y-y_predicted))
        c = -(2/n)*sum(y-y_predicted)
        slope = slope - learning_rate * m
        intercept = intercept - learning_rate * c
        print ("iteration {}: slope--> {}, intercept--> {}, cost--> {}".format(i+1, slope, intercept, cost))
        

x = np.array(df.Present_Price[:50])
y = np.array(df.Selling_Price[:50])

gradient_descent(x,y)
# Out:
# iteration 1: slope--> 0.07544062, intercept--> 0.009309999999999999, cost--> 26.748050000000006
# iteration 2: slope--> 0.14222469092053242, intercept--> 0.017530032667256, cost--> 21.30168826675725
# iteration 3: slope--> 0.20134582953923735, intercept--> 0.024785211321220826, cost--> 17.033853673894235
# iteration 4: slope--> 0.2536836031601824, intercept--> 0.03118628850412577, cost--> 13.689525485568657
# iteration 5: slope--> 0.300016620458068, intercept--> 0.036831304341919134, cost--> 11.068866740925003
# iteration 6: slope--> 0.34103411972714104, intercept--> 0.04180704570278618, cost--> 9.015283072089035
# iteration 7: slope--> 0.37734622700594045, intercept--> 0.04619033787031153, cost--> 7.4060654669490225
# iteration 8: slope--> 0.4094930367523919, intercept--> 0.050049187955614145, cost--> 6.145057838553128
# iteration 9: slope--> 0.4379526502194576, intercept--> 0.05344379706617485, cost--> 5.156911254505854
# ...

# %%
import matplotlib.pyplot as plt

x = df.Present_Price[:50].values 
slope = 0.6781894045399225
intercept = -0.08518158878086576
y_pred = []

for i in x:
    y_pred.append(slope * i + intercept)

plt.scatter(x,y)
plt.plot(x, y_pred, color='red')
plt.show()
